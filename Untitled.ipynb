# %%
import pandas as pd
import numpy as np

# %%
# to put in long format
#long = pd.wide_to_long(processed, stubnames='hosp_', i=['date'], j='hosp')
#long.columns = ['attends']

# %%
# long.to_csv('ts_emergency/data/syn_ts_ed2.csv', index=True)

# %%
l = pd.read_csv('ts_emergency/data/syn_ts_ed2.csv')

# %%
l.pivot_table(values=['attends'], index=['date'], columns=['hosp'])
# Out:
#            attends
# hosp             1    2    3    4
# date
# 2014-04-01     331  287  195  184
# 2014-04-02     340  293  177  181
# 2014-04-03     316  249  183  192
# 2014-04-04     304  313  208  157
# 2014-04-05     292  291  218  166
# ...            ...  ...  ...  ...
# 2014-12-27     346  353  258  198
# 2014-12-28     285  301  214  176
# 2014-12-29     318  266  215  164
# 2014-12-30     308  214  182  164
# 2014-12-31     248  242  174  148
#
# [275 rows x 4 columns]
